# %% [markdown]
# Introduction:
# =============
#
# Welcome to the big scary homework. :) Hopefully between the similar examples in the in-class exercise and the Slack help channel we'll all get through this pretty easily. Please, please, please try some stuff out early on. The exercises build on each other so getting help early is essential.
#
# Tips:
# - Break your code up into a bunch of smallish cells (maybe one or more per question)
# - Use markdown. For the questions that require textual answers, just create a new cell, select it, and change the type in the drop down from Code to Markdown.
# - Partial

# %%
# Magic for displaying graphs and charts
# %matplotlib inline
import pandas as pd
import numpy as np
from sklearn.cross_validation import train_test_split

# %% [markdown]
# Excercise 1: Loading and cleaning data (5 points)
# --------------------------------------
#
# In this exercise, you'll load the data and drop a few weird columns
#
# 1. load the food facts dataset `FoodFacts.csv` into a pandas dataframe
# 2. What are columns 0, 3, 5, 27 and 36?
# 3. Remove columns 3, 5

# %%
df = pd.read_csv("FoodFacts.csv")  # Part 1
# Out:
# C:\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2723: DtypeWarning: Columns (0,3,5,27,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
[df.columns[i] for i in (0,3,5,27,36)]  # Part 2
# Out:
# ['code', 'created_t', 'last_modified_t', 'cities', 'allergens_en']

# %%
df.drop([df.columns[i] for i in (3,5)], axis=1)  # Part 3
# Out:
#                      code                                                url  \
# 0      000000000000012866  http://world-en.openfoodfacts.org/product/0000...
# 1           0000000024600  http://world-en.openfoodfacts.org/product/0000...
# 2           0000000036252  http://world-en.openfoodfacts.org/product/0000...
# 3           0000000039259  http://world-en.openfoodfacts.org/product/0000...
# 4           0000000039529  http://world-en.openfoodfacts.org/product/0000...
# 5           0000001071894  http://world-en.openfoodfacts.org/product/0000...
# 6           0000005200016  http://world-en.openfoodfacts.org/product/0000...
# 7           0000007020254  http://world-en.openfoodfacts.org/product/0000...
# 8           0000010090206  http://world-en.openfoodfacts.org/product/0000...
# 9           0000020364373  http://world-en.openfoodfacts.org/product/0000...
# 10          0000027533024  http://world-en.openfoodfacts.org/product/0000...
# 11          0000027533048  http://world-en.openfoodfacts.org/product/0000...
# 12          0000030053014  http://world-en.openfoodfacts.org/product/0000...
# 13          0000040608754  http://world-en.openfoodfacts.org/product/0000...
# 14               00000758  http://world-en.openfoodfacts.org/product/0000...
# 15          0000084154071  http://world-en.openfoodfacts.org/product/0000...
# 16          0000087177756  http://world-en.openfoodfacts.org/product/0000...
# 17               00001373  http://world-en.openfoodfacts.org/product/0000...
# 18               00002929  http://world-en.openfoodfacts.org/product/0000...
# 19               00003100  http://world-en.openfoodfacts.org/product/0000...
# 20               00005487  http://world-en.openfoodfacts.org/product/0000...
# 21               00007658  http://world-en.openfoodfacts.org/product/0000...
# 22          0000790310013  http://world-en.openfoodfacts.org/product/0000...
# 23          0000790310020  http://world-en.openfoodfacts.org/product/0000...
# 24          0000790310044  http://world-en.openfoodfacts.org/product/0000...
# 25               00008433  http://world-en.openfoodfacts.org/product/0000...
# 26               00008761  http://world-en.openfoodfacts.org/product/0000...
# 27          0000886100252  http://world-en.openfoodfacts.org/product/0000...
# 28          0001000008218  http://world-en.openfoodfacts.org/product/0001...
# 29                 000104  http://world-en.openfoodfacts.org/product/0001...
# ...                   ...                                                ...
# 65473            96092514  http://world-en.openfoodfacts.org/product/9609...
# 14                                           Cauliflower             1
# 15                                      Salsa de mostaza  300 g (neto)
# 16     Boisson gazeuse aux extraits naturels de citro...         33 cl
# 17                                                   NaN             6
# 18                                                   NaN          25 g
# 19                                                   NaN         792 g
# 20                                                   NaN           NaN
# 21                                                   NaN           NaN
# 22                                                   NaN        3.5 oz
# 23                                                   NaN          3 oz
# 24                                            Confiserie           80g
# 25                                                   NaN           0 g
# 26                                                   NaN           NaN
# 27                                                   NaN          33cl
# 28                                                   NaN         500 g
# 29               Assortiment de cakes fourrés aux fruits          980g
# ...                                                  ...           ...
# 65473                                                NaN         250ml
# 65474                                                NaN         250ml
# 65475                                                NaN           NaN
# 65476                                                NaN         100ml
# 65477                                                NaN           NaN
# 65478                                                NaN           NaN
# 65479                                                NaN           NaN
# 65480                                                NaN    16.9 fl oz
# 65481                                                NaN         300ml
# 65482                                                NaN           NaN
# 65483                                                NaN           NaN
# 65484                                                NaN           NaN
# 65485                                                NaN             1
# 65486                                                NaN           NaN
# 65487                                                NaN     Magazine
# 65488                                                NaN         125 g
# 65489                                                NaN           NaN
# 65490                                                NaN          50 g
# 65491                                                NaN         180 g
# 65492                                                NaN           NaN
# 65493                           Bière caribeenne de luxe        330 ml
# 65494                                               Miel         250 g
# 65495                                                NaN             2
# 65496                                                NaN          1 kg
# 65497                                Vins blanc du Bugey        750 ml
# 65498                                              Sprot          170g
# 65499                                  thé bio équitable          50 g
# 65500                                                NaN           NaN
# 65501                                                NaN         180 g
# 65502                    Leba pickle flavor potato chips          50 g
#
#                              packaging                   packaging_tags  \
# 0                         plat cuisiné                     plat-cuisine
# 1                            plastique                        plastique
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
# 5                   Paper,plastic film               paper,plastic-film
# 6                     Sachet plastique                 sachet-plastique
# 7                                  NaN                              NaN
# 8                            aluminium                        aluminium
# 9                                  NaN                              NaN
# 10                        plastic,bowl                     plastic,bowl
# 11                        plastic,bowl                     plastic,bowl
# 12                           emballage                        emballage
# 13                   Canette aluminium                canette-aluminium
# 14                         Plastic,Bag                      plastic,bag
# 15                    Bote de plástico                 bote-de-plastico
# 16                             Canette                          canette
# 17                        elastic band                     elastic-band
# 18                      film - plastic                     film-plastic
# 19                 Barquette,Plastique              barquette,plastique
# 20                                 NaN                              NaN
# 21                                 NaN                              NaN
# 22                                 NaN                              NaN
# 23                                 NaN                              NaN
# 24                 Carton et plastique              carton-et-plastique
# 25                                item                             item
# 26                                 NaN                              NaN
# 27                             Canette                          canette
# 28                             produit                          produit
# 29              Boîte,Carton,Plastique           boite,carton,plastique
# ...                                ...                              ...
# 65473                     Glass,Bottle                     glass,bottle
# 65474                     Glass,Bottle                     glass,bottle
# 65475                              NaN                              NaN
# 65476                              NaN                              NaN
# 65477                              NaN                              NaN
# 65478                 Papier,Plastique                 papier,plastique
# 65479                              NaN                              NaN
# 65480                              NaN                              NaN
# 65481                              NaN                              NaN
# 65482                              NaN                              NaN
# 65483                              NaN                              NaN
# 65484                              NaN                              NaN
# 65485                              NaN                              NaN
# 65486                              NaN                              NaN
# 65487                              NaN                              NaN
# 65488                            boite                            boite
# 65489                              NaN                              NaN
# 65490                        Pot,Métal                        pot,metal
# 65491              Barquette,Plastique              barquette,plastique
# 65492    Boîte,Carton,Sachet,Plastique    boite,carton,sachet,plastique
# 65493  Bouteille en verre transparante  bouteille-en-verre-transparante
# 65494                      Bocal,Verre                      bocal,verre
# 65495                              NaN                              NaN
# 65496                          produit                          produit
# 65497               Bouteille en verre               bouteille-en-verre
# 65498                              NaN                              NaN
# 65499                     boîte,carton                     boite,carton
# 65500                              NaN                              NaN
# 65501                        Pot,Verre                        pot,verre
# 65502                              NaN                              NaN
#
#                 ...           caffeine_100g taurine_100g ph_100g  \
# 0               ...                     NaN          NaN     NaN
# 1               ...                     NaN          NaN     NaN
# 2               ...                     NaN          NaN     NaN
# 3               ...                     NaN          NaN     NaN
# 4               ...                     NaN          NaN     NaN
# 5               ...                     NaN          NaN     NaN
# 6               ...                     NaN          NaN     NaN
# 7               ...                     NaN          NaN     NaN
# 8               ...                     NaN          NaN     NaN
# 9               ...                     NaN          NaN     NaN
# 10              ...                     NaN          NaN     NaN
# 11              ...                     NaN          NaN     NaN
# 12              ...                     NaN          NaN     NaN
# 13              ...                     NaN          NaN     NaN
# 14              ...                     NaN          NaN     NaN
# 15              ...                     NaN          NaN     NaN
# 16              ...                     NaN          NaN     NaN
# 17              ...                     NaN          NaN     NaN
# 18              ...                     NaN          NaN     NaN
# 19              ...                     NaN          NaN     NaN
# 20              ...                     NaN          NaN     NaN
# 21              ...                     NaN          NaN     NaN
# 22              ...                     NaN          NaN     NaN
# 23              ...                     NaN          NaN     NaN
# 24              ...                     NaN          NaN     NaN
# 25              ...                     NaN          NaN     NaN
# 26              ...                     NaN          NaN     NaN
# 27              ...                     NaN          NaN     NaN
# 28              ...                     NaN          NaN     NaN
# 29              ...                     NaN          NaN     NaN
# ...             ...                     ...          ...     ...
# 65473           ...                     NaN          NaN     NaN
# 65474           ...                     NaN          NaN     NaN
# 65475           ...                     NaN          NaN     NaN
# 65476           ...                     NaN          NaN     NaN
# 65477           ...                     NaN          NaN     NaN
# 65478           ...                     NaN          NaN     NaN
# 65479           ...                     NaN          NaN     NaN
# 65480           ...                     NaN          NaN     NaN
# 65481           ...                     NaN          NaN     NaN
# 65482           ...                     NaN          NaN     NaN
# 65483           ...                     NaN          NaN     NaN
# 65484           ...                     NaN          NaN     NaN
# 65485           ...                     NaN          NaN     NaN
# 65486           ...                     NaN          NaN     NaN
# 65487           ...                     NaN          NaN     NaN
# 65488           ...                     NaN          NaN     NaN
# 65489           ...                     NaN          NaN     NaN
# 65490           ...                     NaN          NaN     NaN
# 65491           ...                     NaN          NaN     NaN
# 65492           ...                     NaN          NaN     NaN
# 65493           ...                     NaN          NaN     NaN
# 65494           ...                     NaN          NaN     NaN
# 65495           ...                     NaN          NaN     NaN
# 65496           ...                     NaN          NaN     NaN
# 65497           ...                     NaN          NaN     NaN
# 65498           ...                     NaN          NaN     NaN
# 65499           ...                     NaN          NaN     NaN
# 65500           ...                     NaN          NaN     NaN
# 65501           ...                     NaN          NaN     NaN
# 65502           ...                     NaN          NaN     NaN
#
#       fruits_vegetables_nuts_100g collagen_meat_protein_ratio_100g cocoa_100g  \
# 0                             NaN                              NaN        NaN
# 1                             NaN                              NaN        NaN
# 2                             NaN                              NaN        NaN
# 3                             NaN                              NaN        NaN
# 4                             NaN                              NaN        NaN
# 5                             NaN                              NaN        NaN
# 6                             NaN                              NaN        NaN
# 7                             NaN                              NaN        NaN
# 8                             NaN                              NaN        NaN
# 9                             NaN                              NaN        NaN
# 10                            NaN                              NaN        NaN
# 11                            NaN                              NaN        NaN
# 12                            NaN                              NaN        NaN
# 13                            NaN                              NaN        NaN
# 14                            NaN                              NaN        NaN
# 15                            NaN                              NaN        NaN
# 16                            NaN                              NaN        NaN
# 17                            NaN                              NaN        NaN
# 18                            NaN                              NaN        NaN
# 19                            NaN                              NaN        NaN
# 20                            NaN                              NaN        NaN
# 21                            NaN                              NaN        NaN
# 22                            NaN                              NaN        NaN
# 23                            NaN                              NaN        NaN
# 24                            NaN                              NaN        NaN
# 25                            NaN                              NaN        NaN
# 26                            NaN                              NaN        NaN
# 27                            NaN                              NaN        NaN
# 28                            NaN                              NaN        NaN
# 29                            NaN                              NaN        NaN
# ...                           ...                              ...        ...
# 65473                         NaN                              NaN        NaN
# 65474                         NaN                              NaN        NaN
# 65475                         NaN                              NaN        NaN
# 65476                         NaN                              NaN        NaN
# 65477                         NaN                              NaN        NaN
# 65478                         NaN                              NaN        NaN
# 65479                         NaN                              NaN        NaN
# 65480                         NaN                              NaN        NaN
# 65481                         NaN                              NaN        NaN
# 65482                         NaN                              NaN        NaN
# 65483                         NaN                              NaN        NaN
# 65484                         NaN                              NaN        NaN
# 65485                         NaN                              NaN        NaN
# 65486                         NaN                              NaN        NaN
# 65487                         NaN                              NaN        NaN
# 65488                         NaN                              NaN        NaN
# 65489                         NaN                              NaN        NaN
# 65490                         NaN                              NaN        NaN
# 65491                         NaN                              NaN        NaN
# 65492                         NaN                              NaN        NaN
# 65493                         NaN                              NaN        NaN
# 65494                         NaN                              NaN        NaN
# 65495                         NaN                              NaN        NaN
# 65496                         NaN                              NaN        NaN
# 65497                         NaN                              NaN        NaN
# 65498                         NaN                              NaN        NaN
# 65499                         NaN                              NaN        NaN
# 65500                         NaN                              NaN        NaN
# 65501                         NaN                              NaN        NaN
# 65502                         NaN                              NaN        NaN
#
#       chlorophyl_100g carbon_footprint_100g nutrition_score_fr_100g  \
# 0                 NaN                   NaN                     NaN
# 1                 NaN                   NaN                     NaN
# 2                 NaN                   NaN                     NaN
# 3                 NaN                   NaN                     NaN
# 4                 NaN                   NaN                     NaN
# 5                 NaN                   NaN                     NaN
# 6                 NaN                   NaN                     NaN
# 7                 NaN                   NaN                     NaN
# 8                 NaN                   NaN                     NaN
# 9                 NaN                   NaN                     NaN
# 10                NaN                   NaN                    10.0
# 11                NaN                   NaN                    10.0
# 12                NaN                   NaN                     NaN
# 13                NaN                   NaN                    13.0
# 14                NaN                   NaN                     NaN
# 15                NaN                   NaN                     NaN
# 16                NaN                   NaN                    13.0
# 17                NaN                   NaN                     NaN
# 18                NaN                   NaN                     NaN
# 19                NaN                   NaN                     NaN
# 20                NaN                   NaN                     NaN
# 21                NaN                   NaN                     NaN
# 22                NaN                   NaN                    14.0
# 23                NaN                   NaN                     6.0
# 24                NaN                   NaN                     NaN
# 25                NaN                   NaN                     NaN
# 26                NaN                   NaN                     NaN
# 27                NaN                   NaN                     NaN
# 28                NaN                   NaN                     NaN
# 29                NaN                   NaN                    13.0
# ...               ...                   ...                     ...
# 65473             NaN                   NaN                    17.0
# 65474             NaN                   NaN                     6.0
# 65475             NaN                   NaN                     NaN
# 65476             NaN                   NaN                     NaN
# 65477             NaN                   NaN                     NaN
# 65478             NaN                   NaN                     NaN
# 65479             NaN                   NaN                     NaN
# 65480             NaN                   NaN                     NaN
# 65481             NaN                   NaN                     NaN
# 65482             NaN                   NaN                     NaN
# 65483             NaN                   NaN                     NaN
# 65484             NaN                   NaN                     NaN
# 65485             NaN                   NaN                     NaN
# 65486             NaN                   NaN                     NaN
# 65487             NaN                   NaN                     NaN
# 65488             NaN                   NaN                     NaN
# 65489             NaN                   NaN                     NaN
# 65490             NaN                   NaN                     NaN
# 65491             NaN                   NaN                     NaN
# 65492             NaN                   NaN                    -4.0
# 65493             NaN                   NaN                     NaN
# 65494             NaN                   NaN                     NaN
# 65495             NaN                   NaN                     NaN
# 65496             NaN                   NaN                     NaN
# 65497             NaN                   NaN                     NaN
# 65498             NaN                   NaN                     NaN
# 65499             NaN                   NaN                     2.0
# 65500             NaN                   NaN                     NaN
# 65501             NaN                   NaN                     NaN
# 65502             NaN                   NaN                     NaN
#
#       nutrition_score_uk_100g
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 10                       10.0
# 11                       10.0
# 12                        NaN
# 13                        2.0
# 14                        NaN
# 15                        NaN
# 16                        2.0
# 17                        NaN
# 18                        NaN
# 19                        NaN
# 20                        NaN
# 21                        NaN
# 22                       14.0
# 23                        6.0
# 24                        NaN
# 25                        NaN
# 26                        NaN
# 27                        NaN
# 28                        NaN
# 29                       13.0
# ...                       ...
# 65473                    17.0
# 65474                     6.0
# 65475                     NaN
# 65476                     NaN
# 65477                     NaN
# 65478                     NaN
# 65479                     NaN
# 65480                     NaN
# 65481                     NaN
# 65482                     NaN
# 65483                     NaN
# 65484                     NaN
# 65485                     NaN
# 65486                     NaN
# 65487                     NaN
# 65488                     NaN
# 65489                     NaN
# 65490                     NaN
# 65491                     NaN
# 65492                    -4.0
# 65493                     NaN
# 65494                     NaN
# 65495                     NaN
# 65496                     NaN
# 65497                     NaN
# 65498                     NaN
# 65499                     0.0
# 65500                     NaN
# 65501                     NaN
# 65502                     NaN
#
# [65503 rows x 157 columns]

# %% [markdown]
# Exercise 2: Exploring the Data (20 points)
# ------------------------------
#
# Answer the following questions using some pandas built in operations (slicing, sorting, and basic plotting)
# 1. What percentage of items have a nutrition_score for the uk?
# 2. What's the most caffeinated food?
# 3. What items (top 5) have a lot of arachidonic acid (arachidonic_acid_100g)?
# 4. Based on the data, what would you guess arachidonic acid is used for? (check the categories)
# 5. Make a box plot of the nutritional score for the uk (nutrition_score_uk_100g).
# 6. Do you think there are more healthy or unhealthy foods in this data set? Is the data skewed? Explain.
#
# Hints:
# - http://pandas.pydata.org/pandas-docs/stable/visualization.html#box-plots
# - Don't fuss about making the plot pretty just use the default arguments

# %%
df = pd.read_csv("FoodFacts.csv")  # Part 2.1
# print("\n".join(df.columns))  # Because we need to actually see all the damn columns
print "{0}%".format(df[df["nutrition_score_uk_100g"].notnull()].shape[0]/float(df.shape[0])*100)
# Out:
# 47.7749110728%

# %%
df = pd.read_csv("FoodFacts.csv")  # Part 2.2
print("\n".join([ x for x in df.columns if x.find('caff') != -1 ]))  # Find the damn column
df.loc[df['caffeine_100g'].idxmax()].product_name
# Out:
# caffeine_100g
# 'Red Bull energy drink'

# %%
df = pd.read_csv("FoodFacts.csv")  # Part 2.3
print df.sort_values('arachidonic_acid_100g', ascending=False).head(5).product_name
# Out:
# 12756    Lait Gallia Calisma
# 32423       Dès la naissance
# 55289       Dès la naissance
# 54897          Nidal Natéa 2
# 12835      Gallia croissance
# Name: product_name, dtype: object

# %%
df = pd.read_csv("FoodFacts.csv")  # Part 2.4
print("\n".join([ x for x in df.columns if x.find('category') != -1 ]))  # Find the damn column

print df.sort_values('arachidonic_acid_100g', ascending=False).head(5).main_category

# It's baby food.
# Out:
# main_category
# main_category_en
# 12756    en:baby-foods
# 32423    en:baby-foods
# 55289    en:baby-foods
# 54897    en:baby-foods
# 12835    en:baby-foods
# Name: main_category, dtype: object

# %%
df = pd.read_csv("FoodFacts.csv")  # Part 2.5
df.boxplot(column='nutrition_score_uk_100g', return_type='axes')

# %%
# It appears the food is relatively healthy. Assuming a positive nutrition score is good. The upper 3 quartiles are 0 or above.
df['nutrition_score_uk_100g'].describe()
# Out:
# count    31294.000000
# mean         7.687192
# std          9.501685
# min        -14.000000
# 25%          0.000000
# 50%          5.000000
# 75%         16.000000
# max         33.000000
# Name: nutrition_score_uk_100g, dtype: float64

# %% [markdown]
# Exercise 3: Who's Creating the Data? (30 points)
# ------------------------------------
#
# Explore the "creator" column
#
# Answer the following questions using basic pandas operations (sorting, groupby, aggregation):
# 1. How many unique creators are there in the data?
# 2. What percentage of items are created by open food facts contributers?
# 3. Find the top 10 creators
# 4. Create a bar plot of the number of contributions by each creator for the top 10 creators
#
# Here's some relevant documentation:
# http://pandas.pydata.org/pandas-docs/stable/groupby.html
# http://pandas.pydata.org/pandas-docs/stable/visualization.html#bar-plots
#
# Hints:
# - Use groupby and size to get contributions per creator
# - Just use the df.plot.bar() function without arguments don't worry about scaling or style.

# %%
df = pd.read_csv("FoodFacts.csv")  # Part 3.1
len(set(df['creator']))  # Come at me bro
# Out:
# 1906

# %%
print "{}%".format(df[df['creator'] == "openfoodfacts-contributors"].shape[0]/float(df.shape[0])*100)  # Part 3.2
# Out:
# 24.1424056913%

# %%
df.groupby('creator').size().sort_values(ascending=False).head(10)  # Part 3.3
# Out:
# creator
# openfoodfacts-contributors    15814
# tacite                         4452
# date-limite-app                3980
# sebleouf                       3260
# tacinte                        3189
# javichu                        2544
# stephane                       2367
# jeanbono                       1721
# miles67off                     1406
# teolemon                       1277
# dtype: int64

# %%
df.groupby('creator').size().sort_values(ascending=False).head(10).plot.bar()  # Part 3.4

# %% [markdown]
# Exercise 4: Modeling (30 points)
# --------------------
#
# Here we'll poke at the question "Is there good fat?"
#
# 1. Create a dataframe with only two columns "fat_100g" and "nutrition_score_uk_100g" (drop nulls)
# 2. Create a scatter plot with x being "fat_100g" and y being "nutrition_score_uk_100g"
# 3. Split the data into two random sets: "test" and "train" (70% train, 30% test)
# 4. Fit a linear regression on the train dataset using x as "fat_100g" and y as "nutrition_score_uk_100g"
# 5. Predict nutrition score using the test set
# 6. Plot the scatter plot and line together
# 7. Do the results suprise you? What types of items a lot of fat? Do they have high nutrition scores?
#
# Hint: Use code from in class exercise, just be careful not to accidentally swap x and y

# %%
df = pd.read_csv("FoodFacts.csv")  # Part 4.1
dtf = pd.DataFrame(df, columns=['fat_100g', 'nutrition_score_uk_100g'])
dtf = dtf[dtf['fat_100g'].notnull()]
dtf = dtf[dtf['nutrition_score_uk_100g'].notnull()]
dtf.describe()
# Out:
#            fat_100g  nutrition_score_uk_100g
# count  31150.000000             31150.000000
# mean      12.944672                 7.720899
# std       16.800442                 9.507679
# min        0.000000               -14.000000
# 25%        1.100000                 0.000000
# 50%        6.000000                 5.000000
# 75%       21.000000                16.000000
# max      101.000000                33.000000

# %%
dtf.plot.scatter(x='fat_100g', y='nutrition_score_uk_100g')  # Part 4.2

# %%
dtf = dtf.reindex(np.random.permutation(dtf.index)) # Part 4.2
(train, test) = train_test_split(dtf, test_size=0.3)
print train.size + test.size
print dtf.size
# Out:
# 62300
# 62300

# %%
from sklearn.linear_model import LinearRegression  # Part 4.3
x = train[["fat_100g"]].as_matrix()
y = train["nutrition_score_uk_100g"].as_matrix()

model = LinearRegression().fit(x,y)

# %%
model.predict(test[["fat_100g"]])
# Out:
# array([  2.88785203,  12.26750657,   6.4287658 , ...,   8.19922268,
#          3.1892064 ,   2.96319062])

# %%
import matplotlib.pyplot as plt

plt.scatter(test[["fat_100g"]], test["nutrition_score_uk_100g"])
plt.plot(test[["fat_100g"]], model.predict(test[["fat_100g"]]), color="red")

# %%
df.sort_values("fat_100g", ascending=False).head(10).product_name
# All the highest fat things are oils. Nutrition scores from OECD nations have tended toward unsaturated fats so determination
# nutritional score is likely directly correlated to the unsaturated fat content.
# Out:
# (65503, 159)

# %% [markdown]
# Exercise 5: Machine Learning Theory (15 points)
# -----------------------------------
#
# A lot of times simply applying the correct model makes more of a difference than clean data. This exercise shows off your knowledge of the theory behind different machine learning concepts.
#
# 1. If you were going to create your own nutritional rating, based off of (the very incomplete) UK and French rankings which class of machine learning model would you choose? Why? Which scikit learn model would you choose? Why? Assume your rating would be between 0 and 100.
#
# 2. If you wanted to group foods into 10 categories based on their nutritional facts and keywords in their product names, which type of machine learning model would you use? Why? Which scikit learn model would you choose? Why?
#
# 3. If you wanted to try to detect outliers (malicious users, data corruption, etc) what type of model could you use? Why? Is there anything in scikit learn that can handle this task?

# %% [markdown]
# 1. If we are going to make a rating, we want to have continuous values. This means we should pick some sort of regression model. Our machine learning model is... The handy Scikit learn flow chat suggests we want to use .
